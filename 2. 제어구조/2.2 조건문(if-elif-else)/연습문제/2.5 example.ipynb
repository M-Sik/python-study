# %%
from IPython.display import Image

# %% [markdown]
# # 연습 문제 2.5 : 윤년 판별하기

# %% [markdown]
# # 문제

# %% [markdown]
# 윤년은 역법을 실제 태양년에 맞추기 위해 여분의 하루 또는 월을 끼우는 해입니다. 현재 사용하는 그레고리력의 윤년 규칙은 다음과 같습니다.

# %% [markdown]
# 1. 서력 기원 연수가 4로 나누어 떨어지는 해는 윤년으로 한다. (1988년, 1992년, 1996년, 2004년, 2008년, 2012년, 2016년, 2020년, 2024년, 2028년 ....)

# %% [markdown]
# 2. 서력 기원 연수가 4, 100으로 나누어 떨어지는 해는 평년으로 한다. (1900년, 2100년, 2200년, 2300년, 2500년.....)

# %% [markdown]
# 3. 서력 기원 연수가 4, 100, 400으로 나누어 떨어지는 해는 윤년으로 둔다. (2000년, 2400년....)

# %% [markdown]
# 이 규칙을 나타내는 흐름도를 그려보았다.

# %%
Image("./1111.png")

# %% [markdown]
# 이 규칙에 따라, 연도를 나타내는 저수를 입력으로 받아서 윤년인지 아닌지 출력하는 프로그램을 작성하시오.

# %%
year = int(input('연도 입력 :'))

if(year%4 == 0):
    if(year%100 == 0):
        if(year%400 == 0):
            print('윤년')
        else:
            print('평년')
    else:
        print("윤년")
else:
    print('평년')
# Out:
# 연도 입력 :400
# 윤년
